# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import seaborn as sns

# %%
df1 = pd.read_csv('df1',index_col=0)
df2 = pd.read_csv('df2')
df4 = sns.load_dataset('tips')

# %%
df2.head(3)
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510

# %%
df1['A'].hist()

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df1["A"].hist()

# %%
plt.style.use('ggplot')

# %%
df1['A'].hist()

# %%
plt.style.use("dark_background")

# %%
df1['A'].hist()

# %%
df2.plot.area(alpha=0.8)

# %%
df2.plot.bar()

# %%
df2.plot.kde()

# %%
df2.plot.barh()

# %%
df2.plot.hist()

# %%
df2.plot.line()

# %%
df2.plot.density()

# %%
df2.plot.bar(stacked = True)

# %%
df2.plot.hist(bins=15)

# %%
#df1.plot.line(x=df1.index, y='B',figsize = (12,4), lw= 1)
#df1.plot.line(x=df1.index,y='B',figsize=(12,3),lw=1)
plt.style.use('dark_background')

# %%
#df1.plot.scatter(x='A', y="B",cmap = 'coolwarm')
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm', s=df1['C']*150)
# Out:
# /home/stephen/anaconda3/lib/python3.6/site-packages/matplotlib/collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df = pd.read_csv("Black_Friday.csv")

# %%
df.plot.()

# %%
df.plot.scatter(x="Purchase", y="Product_Category_1", c="Product_Category_1",cmap="coolwarm", s = df["Purchase"]*100)

# %%
df1.plot.box()

# %%
df4.plot.hist()

# %% [markdown]
# ## The End

# %% [markdown]
# Please contact me for clarifications and concerns: nderituwangui50@gmail.com or via linkedin https://www.linkedin.com/in/stephen-nderitu-260227123/
